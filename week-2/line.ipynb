# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/spotify.csv", parse_dates=["Date"])

# df["Date"] = pd.to_datetime(df["Date"])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      366 non-null    datetime64[ns]
#  1   Shape of You              366 non-null    int64
#  2   Despacito                 359 non-null    float64
#  3   Something Just Like This  319 non-null    float64
#  4   HUMBLE.                   282 non-null    float64
#  5   Unforgettable             275 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 17.3 KB

# %%
plt.plot(df["Date"], df["Shape of You"], label="Shape of You")
plt.plot(df["Date"], df["Despacito"], label="Despacito")
plt.plot(df["Date"], df["Something Just Like This"], label="Something Just Like This")

plt.legend()

plt.show()

# %%
df = pd.read_csv("data/spotify.csv", index_col="Date", parse_dates=True)

df.plot()
# Out:
# <Axes: xlabel='Date'>
