# %%
import matplotlib.pyplot as plt

plt.plot([0, 1, 2, 3])

plt.show()

# %%
plt.plot([2, 2], [2, 4])
plt.plot([4, 4], [2, 4])
plt.plot([0, 2, 4, 6], [1, 0, 0, 1])

plt.show()

# %%
import matplotlib.pyplot as plt

y = [5, 3, 6, 4]
x = [0, 1, 2, 3]

plt.plot(x, y)
plt.title("Cool graph")
plt.xlabel("Label x")
plt.ylabel("Label y")

plt.show()
